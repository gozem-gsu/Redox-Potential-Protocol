2666.54780852573,
2671.36385370634,
2664.64631557076,
3120.24593115444,
2762.07959800467,
2744.00480275512,
2750.64533423034,
2678.23540514409,
2879.58576709650,
3014.35933161161,
2607.58988083939,
2771.42420592363,
3152.89571884628,
2947.32713370251,
2813.57582572414



])
x4 = np.array([-645,
-602,
-1142,
-827,
-1254,
-1406,
-1414,
-1461,
-1061,
-1040,

-1401,
-1367,
-1257,

-704,
-712,
-700,


-268,
-1503,


])
y4 = np.array([3616.69999895180,
3671.40247898281,
2812.68374579902,
2969.98624668670,
3039.37158294580,
2694.97112813537,
2753.18217290195,
2563.09943559609,
2727.11479434695,
2902.18490739744,

2630.91478846110,
2760.03152030038,
2622.61333500588,

3370.35478457106,
3013.74931917783,
3089.81475144892,



3973.29330110486,
2378.58332706484,



])
# Fit linear regression models
#model1 = LinearRegression().fit(x1.reshape(-1, 1), y1)
#model2 = LinearRegression().fit(x2.reshape(-1, 1), y2)
#model3 = LinearRegression().fit(x3.reshape(-1, 1), y3)
#model4 = LinearRegression().fit(x4.reshape(-1, 1), y4)

# Make predictions
y1_pred = x1+4088.56
y2_pred = x2+4087.4517
y3_pred = x3+4108.506
y4_pred = x4+4019.66

# Calculate MAE
mae_1 = mean_absolute_error(y1, y1_pred)
mae_2 = mean_absolute_error(y2, y2_pred)
mae_3 = mean_absolute_error(y3, y3_pred)
mae_4 = mean_absolute_error(y4, y4_pred)

# Calculate Pearson correlation coefficients
r_1, _ = pearsonr(y1, y1_pred)
r_2, _ = pearsonr(y2, y2_pred)
r_3, _ = pearsonr(y3, y3_pred)
r_4, _ = pearsonr(y4, y4_pred)

# Assign y-intercept variables
intercept_1 = 4088.56
intercept_2 = 4087.4517
intercept_3 = 4108.506
intercept_4 = 4019.66

# Set the font size globally
plt.rc('font', size=13)

# Your plotting code
plt.scatter(x1, y1, color='blue', label='Benzoquinones')
plt.scatter(x3, y3, color='red', label='Naphthoquinones')
plt.scatter(x2, y2, color='green', label='Anthraquinones')
plt.scatter(x4, y4, color='purple', label='Other quinones')

plt.plot(x1, y1_pred, color='blue', linewidth=2.5, label=f'$r$: {r_1:.2f}, MAE: {mae_1:.2f}\ny-intercept: {intercept_1:.0f}')
plt.plot(x3, y3_pred, color='red', linewidth=2.5, label=f'$r$: {r_3:.2f}, MAE: {mae_3:.2f}\ny-intercept: {intercept_3:.0f}')
plt.plot(x2, y2_pred, color='green', linewidth=2.5, label=f'$r$: {r_2:.2f}, MAE: {mae_2:.2f}\ny-intercept: {intercept_2:.0f}')
plt.plot(x4, y4_pred, color='purple', linewidth=2.5, label=f'$r$: {r_4:.2f}, MAE: {mae_4:.2f}\ny-intercept: {intercept_4:.0f}')

plt.xlabel('Experimental redox potential relative to SCE [mV]', fontsize=13)
plt.ylabel('Absolute computed redox potential  [mV]', fontsize=13)
plt.xticks(fontsize=13)  # Increase font size of x-axis tick labels
plt.yticks(fontsize=13)  # Increase font size of y-axis tick labels
# Move the legend to the right of the graph
legend = plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), edgecolor='black')
frame = legend.get_frame()
frame.set_linewidth(1.5)  # Set the border width of the legend box
# Set edge linewidth
plt.gca().spines['top'].set_linewidth(1.5)  # top edge
plt.gca().spines['bottom'].set_linewidth(1.5)  # bottom edge
plt.gca().spines['left'].set_linewidth(1.5)  # left edge
plt.gca().spines['right'].set_linewidth(1.5)  # right edge


plt.show()
